# %% [markdown]
# ## 작업형1

# %% [markdown]
# ### 문제1
# 1. 대륙('continent')별 맥주 소비량(‘beer_servings’)의 평균을 계산하고, 평균이 가장
#  큰 대륙을 찾으시오.
# 2. 1번에서 찾은 대륙에서 맥주 소비량이 5번째로 많은 국가(‘country’)의 맥주 소비량을 구하시오.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/8_1/drinks.csv")
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.groupby('continent')['beer_servings'].mean().nlargest(1)
# Out:
# continent
# Europe    193.777778
# Name: beer_servings, dtype: float64

# %%
cond = df['continent'] == 'Europe'
df[cond]['beer_servings'].nlargest(5).iloc[-1]
# Out:
# np.int64(313)

# %% [markdown]
# ### 문제2
# 1. ‘관광객비율’이 두 번째로 높은 국가의 ‘사업’ 방문객 수를 a라고 정의하시오.
# 2. ‘관광’이 두 번째로 높은 국가의 ‘공무’ 방문객 수를 b라고 정의하시오.
# 3. a와 b의 합을 구하시오.
# - 방문객 합계 = 관광 + 공무 + 사업 + 기타
# - 관광객 비율 = 관광 / 방문객 합계

# %%
# 방법1
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/8_1/tourist.csv")
df.head()
# Out:
#     나라    관광   공무   사업   기타
# 0  국가1  1184  270  380   55
# 1  국가2  1059  184  267   86
# 2  국가3  1129  168  261   50
# 3  국가4   692  106  214  125
# 4  국가5  1335  296  296   84

# %%
df['관광객비율'] = df['관광'] / (df['관광'] + df['공무'] + df['사업'] + df['기타'])
df.head()
# Out:
#     나라    관광   공무   사업   기타     관광객비율
# 0  국가1  1184  270  380   55  0.626787
# 1  국가2  1059  184  267   86  0.663534
# 2  국가3  1129  168  261   50  0.702114
# 3  국가4   692  106  214  125  0.608619
# 4  국가5  1335  296  296   84  0.663849

# %%
df1 = df.sort_values('관광객비율', ascending=False)
df1.head()
# df.iloc(84)
# 203
a = 203
# Out:
#       나라    관광   공무   사업   기타     관광객비율
# 88  국가89  1370  103  227   75  0.771831
# 84  국가85  1499  130  203  114  0.770298
# 85  국가86  1437  124  231  125  0.749609
# 30  국가31  1277  136  231   62  0.748535
# 50  국가51  1461  198  203   96  0.746170

# %%
df2 = df.sort_values('관광', ascending=False)
df2.head()
b = 238

a+b
# Out:
# 441

# %%
# 방법2
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/8_1/tourist.csv")
df['방문객합계'] = df['관광'] + df['공무'] + df['사업'] + df['기타']
df['관광객비율'] = df['관광'] / df['방문객합계']
df.nlargest(2, '관광객비율')
# Out:
#       나라    관광   공무   사업   기타  방문객합계     관광객비율
# 88  국가89  1370  103  227   75   1775  0.771831
# 84  국가85  1499  130  203  114   1946  0.770298

# %% [markdown]
# ### 문제3
# 1. 주어진 데이터에서 ‘co’와 ‘nmhc’ 컬럼을 각각 Min-Max 스케일링하시오.
# 2. 스케일링된 ‘co’, ‘nmhc’ 컬럼의 표준편차를 각각 구하시오.
# 3. ‘co’ 컬럼의 표준편차에서 ‘nmhc’ 컬럼의 표준편차를 뺀 값을 소수점 3자리로 반올림하여 구하시오.
# - Min-Max 스케일링 = (X - min_X) / (max_X - min_X)
# - X 변수의 최솟값: min_X
# - X 변수의 최댓값: max_X

# %%
# 방법1
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/8_1/chem.csv")
df.head()
# Out:
#   sample   co  nmhc  etc
# 0    샘플1   79    54   31
# 1    샘플2   84    57   58
# 2    샘플3  109    74  113
# 3    샘플4   15    77   21
# 4    샘플5   65    77  115

# %%
min_co = df['co'].min()
max_co = df['co'].max()
df['co'] = (df['co'] - min_co) / (max_co - min_co)

min_nmhc = df['nmhc'].min()
max_nmhc = df['nmhc'].max()
df['nmhc'] = (df['nmhc'] - min_nmhc) / (max_nmhc - min_nmhc)

std_co = df['co'].std()
std_nmhc = df['nmhc'].std()
round(std_co - std_nmhc, 3)
# Out:
# -0.017

# %%
# 방법2
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/8_1/chem.csv")
