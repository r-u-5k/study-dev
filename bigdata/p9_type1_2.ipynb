# %% [markdown]
# ## 작업형1

# %% [markdown]
# ### 문제1

# %% [markdown]
# 1. 총대출액은 신용대출과 담보대출의 합이다.
# 2. 각 지역코드 내에서, 성별(예: 1과 2)별로 '총대출액'의 합계를 계산하시오.
# 3. 성별 간 총대출액의 차이가 가장 큰 지역코드를 구하시오.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/9_1/loan.csv")
df.head()
# Out:
#          지역코드  성별    신용대출     담보대출
# 0  4100000000   1  688608  5706058
# 1  4100000000   2  611035  2260521
# 2  4100000001   1  125392  5946493
# 3  4100000001   2  239679  4711962
# 4  4100000002   1  623758  5411745

# %%
df['총대출액'] = df['신용대출'] + df['담보대출']
df.head()
# Out:
#          지역코드  성별    신용대출     담보대출     총대출액
# 0  4100000000   1  688608  5706058  6394666
# 1  4100000000   2  611035  2260521  2871556
# 2  4100000001   1  125392  5946493  6071885
# 3  4100000001   2  239679  4711962  4951641
# 4  4100000002   1  623758  5411745  6035503

# %%
df2 = df.groupby(['지역코드', '성별'])['총대출액'].sum()
df2.head()
# Out:
# 지역코드        성별
# 4100000000  1     22891981
#             2     18339609
# 4100000001  1     34197683
#             2     17595557
# 4100000002  1     13119017
# Name: 총대출액, dtype: int64

# %%
df2 = df2.unstack()
df2.head()
# Out:
# 성별                 1         2
# 지역코드
# 4100000000  22891981  18339609
# 4100000001  34197683  17595557
# 4100000002  13119017  21827691
# 4100000003  16549091  54654134
# 4100000004  26831399  56145359

# %%
df2['차이'] = abs(df2[1] - df2[2])
df2.head()
# Out:
# 성별                 1         2        차이
# 지역코드
# 4100000000  22891981  18339609   4552372
# 4100000001  34197683  17595557  16602126
# 4100000002  13119017  21827691   8708674
# 4100000003  16549091  54654134  38105043
# 4100000004  26831399  56145359  29313960

# %%
df2['차이'].idxmax()
# 4100000278
# Out:
# np.int64(4100000278)

# %% [markdown]
# ### 문제2

# %% [markdown]
# 1. 검거율은 검거건수 / 발생건수이다.
# 2. 각 연도에서 가장 높은 검거율을 기록한 범죄유형을 찾으시오.
# 3. 해당 범죄유형의 검거건수를 구한 후, 이 값들을 모두 합산하시오. (정수로 구하시오)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/9_1/crime.csv")
df.head()
# Out:
#      연도    구분  강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  \
# 0  2014  발생건수   800   900   750   650   700    1034   600   850   800   900
# 1  2014  검거건수   500   600   400   450   400     961   350   500   450   550
# 2  2015  발생건수   900   768   800   750   700    1000   850   800   900   950
# 3  2015  검거건수   600   713   500   550   400     600   500   450   550   600
# 4  2016  발생건수   850   800   880   750   700     950   900   800   850   900
#
#    노동범죄  선거범죄  병역범죄  기타범죄
# 0   750   800   700  1000
# 1   400   450   400   600
# 2   800   850   750  1000
# 3   450   500   400   600
# 4   750   800   700   950

# %%
df1 = df[df['구분'] == '발생건수']
df2 = df[df['구분'] == '검거건수']
print(df1.head())
print(df2.head())
# Out:
#      연도    구분  강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  \
# 0  2014  발생건수   800   900   750   650   700    1034   600   850   800   900
# 2  2015  발생건수   900   768   800   750   700    1000   850   800   900   950
# 4  2016  발생건수   850   800   880   750   700     950   900   800   850   900
# 6  2017  발생건수  1000   900   850   800   750     950  1400   900  1000   950
# 8  2018  발생건수  1450   900   850   800   750     950   900   800   850   900
#
#    노동범죄  선거범죄  병역범죄  기타범죄
# 0   750   800   700  1000
# 2   800   850   750  1000
# 4   750   800   700   950
# 6   800   850   750   900
# 8   750   800   700   950
#      연도    구분  강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  \
# 1  2014  검거건수   500   600   400   450   400     961   350   500   450   550
# 3  2015  검거건수   600   713   500   550   400     600   500   450   550   600
# 5  2016  검거건수   500   600   812   550   400     600   500   450   500   550
# 7  2017  검거건수   600   500   500   550   400     600  1300   500   550   600
# 9  2018  검거건수  1350   600   500   550   400     600   500   450   500   550
#
#    노동범죄  선거범죄  병역범죄  기타범죄
# 1   400   450   400   600
# 3   450   500   400   600
# 5   400   450   400   600
# 7   450   500   400   500
# 9   400   450   400   600

# %%
df1 = df1.reset_index(drop=True) # 발생건수
df2 = df2.reset_index(drop=True) # 검거건수
print(df1.head())
print(df2.head())
# Out:
#      연도    구분  강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  \
# 0  2014  발생건수   800   900   750   650   700    1034   600   850   800   900
# 1  2015  발생건수   900   768   800   750   700    1000   850   800   900   950
# 2  2016  발생건수   850   800   880   750   700     950   900   800   850   900
# 3  2017  발생건수  1000   900   850   800   750     950  1400   900  1000   950
# 4  2018  발생건수  1450   900   850   800   750     950   900   800   850   900
#
#    노동범죄  선거범죄  병역범죄  기타범죄
# 0   750   800   700  1000
# 1   800   850   750  1000
# 2   750   800   700   950
# 3   800   850   750   900
# 4   750   800   700   950
#      연도    구분  강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  \
# 0  2014  검거건수   500   600   400   450   400     961   350   500   450   550
# 1  2015  검거건수   600   713   500   550   400     600   500   450   550   600
# 2  2016  검거건수   500   600   812   550   400     600   500   450   500   550
# 3  2017  검거건수   600   500   500   550   400     600  1300   500   550   600
# 4  2018  검거건수  1350   600   500   550   400     600   500   450   500   550
#
#    노동범죄  선거범죄  병역범죄  기타범죄
# 0   400   450   400   600
# 1   450   500   400   600
# 2   400   450   400   600
# 3   450   500   400   500
# 4   400   450   400   600

# %%
df3 = df1.iloc[:, 2:] # 발생건수
df4 = df2.iloc[:, 2:] # 검거건수
print(df3.head())
print(df4.head())
# Out:
#    강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  노동범죄  선거범죄  \
# 0   800   900   750   650   700    1034   600   850   800   900   750   800
# 1   900   768   800   750   700    1000   850   800   900   950   800   850
# 2   850   800   880   750   700     950   900   800   850   900   750   800
# 3  1000   900   850   800   750     950  1400   900  1000   950   800   850
# 4  1450   900   850   800   750     950   900   800   850   900   750   800
#
#    병역범죄  기타범죄
# 0   700  1000
# 1   750  1000
# 2   700   950
# 3   750   900
# 4   700   950
#    강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  노동범죄  선거범죄  \
# 0   500   600   400   450   400     961   350   500   450   550   400   450
# 1   600   713   500   550   400     600   500   450   550   600   450   500
# 2   500   600   812   550   400     600   500   450   500   550   400   450
# 3   600   500   500   550   400     600  1300   500   550   600   450   500
# 4  1350   600   500   550   400     600   500   450   500   550   400   450
#
#    병역범죄  기타범죄
# 0   400   600
# 1   400   600
# 2   400   600
# 3   400   500
# 4   400   600

# %%
df_rate = df4 / df3
df_rate.head()
# Out:
#        강력범죄      절도범죄      폭력범죄      지능범죄      풍속범죄    특별경제범죄      마약범죄  \
# 0  0.625000  0.666667  0.533333  0.692308  0.571429  0.929400  0.583333
# 1  0.666667  0.928385  0.625000  0.733333  0.571429  0.600000  0.588235
# 2  0.588235  0.750000  0.922727  0.733333  0.571429  0.631579  0.555556
# 3  0.600000  0.555556  0.588235  0.687500  0.533333  0.631579  0.928571
# 4  0.931034  0.666667  0.588235  0.687500  0.533333  0.631579  0.555556
#
#        보건범죄      환경범죄      교통범죄      노동범죄      선거범죄      병역범죄      기타범죄
# 0  0.588235  0.562500  0.611111  0.533333  0.562500  0.571429  0.600000
# 1  0.562500  0.611111  0.631579  0.562500  0.588235  0.533333  0.600000
# 2  0.562500  0.588235  0.611111  0.533333  0.562500  0.571429  0.631579
# 3  0.555556  0.550000  0.631579  0.562500  0.588235  0.533333  0.555556
# 4  0.562500  0.588235  0.611111  0.533333  0.562500  0.571429  0.631579

# %%
list1 = df_rate.idxmax(axis=1)
list1
# Out:
# 0    특별경제범죄
# 1      절도범죄
# 2      폭력범죄
# 3      마약범죄
# 4      강력범죄
# 5      보건범죄
# 6      지능범죄
# dtype: object

# %%
result = 0
for i in range(len(list1)):
  print(df4.loc[i, list1[i]])
  result += df4.loc[i, list1[i]]
result
# Out:
# 961
# 713
# 812
# 1300
# 1350
# 1300
# 1363
# np.int64(7799)

# %%
df4
# Out:
#    강력범죄  절도범죄  폭력범죄  지능범죄  풍속범죄  특별경제범죄  마약범죄  보건범죄  환경범죄  교통범죄  노동범죄  선거범죄  \
# 0   500   600   400   450   400     961   350   500   450   550   400   450
# 1   600   713   500   550   400     600   500   450   550   600   450   500
# 2   500   600   812   550   400     600   500   450   500   550   400   450
# 3   600   500   500   550   400     600  1300   500   550   600   450   500
# 4  1350   600   500   550   400     600   500   450   500   550   400   450
# 5   600   500   500   550   400     600   500  1300   550   600   450   500
# 6   600   500   500  1363   400     600   500   450   500   550   400   450
#
#    병역범죄  기타범죄
# 0   400   600
# 1   400   600
# 2   400   600
# 3   400   500
# 4   400   600
# 5   400   500
# 6   400   600

# %%
# df4.index = [2014+i for i in range(0, 7)]
# df4

# %% [markdown]
# ### 문제3

# %% [markdown]
# 1. 만족도의 결측치는 만족도의 평균값으로 대체한다.
# 2. 근속연수의 결측치는 동일한 부서 및 성과등급에 해당하는 직원들의 평균 근속연수로 대체한다. (이때, 평균 근속연수는 소수점 이하를 절사하여 정수로 변환하여 사용)
# 3. 각 직원의 '연봉 / 근속연수' 값을 계산하여, 그 값이 세 번째로 큰 직원의 근속연수를 구하시오.
# 4. 각 직원의 '연봉 / 만족도' 값을 계산하여, 그 값이 두 번째로 큰 직원의 교육참가횟수를 구하시오.
# 5. (3)과 (4)의 값을 더한 결과를 구하시오. (정수로 구하시오)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/9_1/hr.csv")
df.head()
# Out:
#     사원번호         부서 성과등급         연봉  근속연수  교육참가횟수  만족도
# 0  E0001  Marketing    B   73200000  14.0       5  6.0
# 1  E0002         IR    A   95100000   3.0       4  9.0
# 2  E0003    Manager    B   44700000   5.0       2  8.0
# 3  E0004         IR    B  122100000  16.0       3  8.0
# 4  E0005         IR    C   66000000   NaN       4  8.0

# %%
df['만족도'] = df['만족도'].fillna(df['만족도'].mean())
df['근속연수'].fillna((df.groupby(['부서', '성과등급'])['근속연수'].transform('mean')).astype(int))
# Out:
# 0      14.0
# 1       3.0
# 2       5.0
# 3      16.0
# 4      10.0
#        ...
# 995    15.0
# 996    12.0
# 997     4.0
# 998     8.0
# 999     9.0
# Name: 근속연수, Length: 1000, dtype: float64

# %%
df['연봉/근속연수'] = df['연봉'] / df['근속연수']
df.nlargest(5, '연봉/근속연수')
# 1
# Out:
#       사원번호         부서 성과등급         연봉  근속연수  교육참가횟수       만족도      연봉/근속연수
# 357  E0358    Finance    B  148100000   1.0       5  8.000000  148100000.0
# 386  E0387         HR    A  145400000   1.0       1  9.000000  145400000.0
# 801  E0802         IR    A  144900000   1.0       5  5.017045  144900000.0
# 145  E0146      Sales    C  144800000   1.0       5  5.000000  144800000.0
# 499  E0500  Marketing    C  143700000   1.0       6  5.017045  143700000.0

# %%
df['연봉/만족도'] = df['연봉'] / df['만족도']
df.nlargest(3, '연봉/만족도')
# 6
# Out:
#       사원번호       부서 성과등급         연봉  근속연수  교육참가횟수  만족도       연봉/근속연수  \
# 490  E0491  Finance    B  149000000  13.0       6  1.0  1.146154e+07
# 737  E0738       HR    A  146200000   9.0       6  1.0  1.624444e+07
# 408  E0409  Finance    B  146100000   6.0       3  1.0  2.435000e+07
#
#           연봉/만족도
# 490  149000000.0
# 737  146200000.0
# 408  146100000.0
