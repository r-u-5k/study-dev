# %% [markdown]
# # 작업형3

# %% [markdown]
# ## 문제1.
#
# 제공된 데이터(attrition.csv)는 직원의 나이, 연봉, 근무 특성 등에 따른 이직 여부(attrition)에 관한 자료이다.
# 이 데이터를 이용하여 로지스틱 회귀분석(Logistic Regression)을 수행하고, 제시된 소문항에 답하시오.
#
# [제공 데이터]
# - attrition : 이직 여부 (0 = 잔류, 1 = 이직) 종속변수
# - age : 나이 (정수형)
# - income : 연봉 (정수형)
# - overtime : 초과근무 여부 (0 = 아니오, 1 = 예)

# %% [markdown]
# ### 문제1-1. 로지스틱 회귀모델을 적합한 후, p-value가 0.05보다 작은 변수의 회귀계수를 구하시오. 단 절편항(상수항)은 제외한다. (반올림하여 소수 셋째 자리까지 작성)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_3/attrition.csv")

# 1) 로지스틱 회귀분석 수행
from statsmodels.formula.api import logit
model = logit('attrition ~ age + income + overtime', data=df).fit()

# 2) 회귀 분석 결과 출력
model.summary()

# 3) income 회귀계수 출력

# 정답: -0.002
# Out:
# Optimization terminated successfully.
#          Current function value: 0.387298
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              attrition   No. Observations:                 6000
# Model:                          Logit   Df Residuals:                     5996
# Method:                           MLE   Df Model:                            3
# Date:                Mon, 24 Nov 2025   Pseudo R-squ.:                  0.4215
# Time:                        04:36:08   Log-Likelihood:                -2323.8
# converged:                       True   LL-Null:                       -4016.9
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 문제1-2. 나이(age)가 1 증가할 때 이직할 오즈비(Odds Ratio)를 구하시오.(반올림하여 소수 셋째 자리까지 작성)

# %%
# 1) 오즈비 계산
import numpy as np
np.exp(model.params['age'])
# 2) 반올림 후 결과 출력

# 정답: 0.996
# Out:
# np.float64(0.9955919012811981)

# %% [markdown]
# ### 문제1-3. 새로운 직원(age=40, income=4500, overtime=1)에 대해, 모델을 이용하여 이직 확률을 예측하시오.(반올림하여 소수 셋째 자리까지 작성)

# %%
# 1) 새로운 직원 데이터 만들기
new = pd.DataFrame({'age': [40], 'income': [4500], 'overtime': [1]})
# 2) 예측
model.predict(new)
# 3) 반올림 후 결과 출력
# Out:
# 0    0.696917
# dtype: float64

# %% [markdown]
# ## 문제2.
#
# 제공된 데이터(heating_load.csv)는 건물 특성과 난방 부하(heating_load)에 관한 자료이다.
# 다중회귀분석을 수행하고 제시된 소문항에 답하시오.
#
# [제공 데이터]
# - heating_load : 난방 부하 (종속변수)
# - wall : 벽체 면적
# - roof : 지붕 면적
# - glazing : 유리(창호) 면적
# - height : 건물 높이

# %% [markdown]
# ### 문제2-1. 모든 독립변수를 포함한 회귀모형을 적합하시오. 이때 절편을 제외한 회귀계수의 합을 구하시오.(반올림하여 소수 셋째 자리까지 작성)

# %%
import pandas as pd

# 1) 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_3/heating.csv")

# 2) 다중선형회귀분석 (모든 변수 사용)
from statsmodels.formula.api import ols
model = ols('heating_load ~ wall + roof + glazing + height', data=df).fit()
# 3) 회귀 분석 결과 출력
model.summary()
# 4) 절편 제외 회귀계수들의 합 구하기
# model.params[1:].sum()
# 정답: 0.254
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           heating_load   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     417.8
# Date:                Mon, 24 Nov 2025   Prob (F-statistic):          2.02e-164
# Time:                        05:11:51   Log-Likelihood:                -1772.0
# No. Observations:                 550   AIC:                             3554.
# Df Residuals:                     545   BIC:                             3576.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     38.3821      1.504     25.517      0.000      35.427      41.337
# ...

# %% [markdown]
# ### 문제2-2. 유의한 변수(유의수준 0.05 이하)만을 사용하여 다중회귀분석을 다시 수행하고, R²(결정계수) 값을 구하시오. (반올림하여 소수 셋째 자리까지 작성)

# %%
# 1) 다시 회귀 분석
model = ols('heating_load ~ roof + glazing + height', data=df).fit()

# 2) 결정계수(R-squared) 확인
model.summary()
# 정답: 0.754
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           heating_load   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     556.7
# Date:                Mon, 24 Nov 2025   Prob (F-statistic):          1.31e-165
# Time:                        05:19:55   Log-Likelihood:                -1772.5
# No. Observations:                 550   AIC:                             3553.
# Df Residuals:                     546   BIC:                             3570.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.2337      1.247     31.467      0.000      36.784      41.683
# ...

# %% [markdown]
# ### 문제2-3. 새로운 건물(wall=20, roof=150, glazing=20, height=5)이 주어졌을 때, 2-2문제에서 사용한 모델을 이용하여 난방 부하(heating_load)를 예측하시오. (반올림하여 소수 셋째 자리까지 작성)

# %%
# 1) 새로운 데이터 (예: 문제에서 제시된 값)
new = pd.DataFrame({'wall': [20], 'roof': [150], 'glazing': [20], 'height': [5]})
# 2) 예측값 계산
model.predict(new)
# 3) 반올림 후 출력

# 정답: 79.612
# Out:
# 0    79.611549
# dtype: float64
